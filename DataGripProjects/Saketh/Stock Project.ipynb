# %%
import requests
import pandas as pd

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=06X8NXLCP3G75HVK'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2023-03-16 20:00:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2023-03-16 20:00:00': {'1. open': '124.8700', '2. high': '124.8700', '3. low': '124.8700', '4. close': '124.8700', '5. volume': '207'}, '2023-03-16 19:15:00': {'1. open': '124.7900', '2. high': '124.8000', '3. low': '124.7900', '4. close': '124.8000', '5. volume': '1000'}, '2023-03-16 17:00:00': {'1. open': '124.7000', '2. high': '124.8000', '3. low': '124.7000', '4. close': '124.8000', '5. volume': '583'}, '2023-03-16 16:45:00': {'1. open': '124.7900', '2. high': '124.7900', '3. low': '124.7900', '4. close': '124.7900', '5. volume': '195'}, '2023-03-16 16:20:00': {'1. open': '124.7000', '2. high': '124.7000', '3. low': '124.7000', '4. close': '124.7000', '5. volume': '2418'}, '2023-03-16 16:15:00': {'1. open': '124.7000', '
# ...

# %%
df=pd.read_json(url)

df.head(10)
# Out:
#                                                              Meta Data  \
# 1. Information       Intraday (5min) open, high, low, close prices ...
# 2. Symbol                                                          IBM
# 3. Last Refreshed                                  2023-03-16 20:00:00
# 4. Interval                                                       5min
# 5. Output Size                                                 Compact
# 6. Time Zone                                                US/Eastern
# 2023-03-16 20:00:00                                                NaN
# 2023-03-16 19:15:00                                                NaN
# 2023-03-16 17:00:00                                                NaN
# 2023-03-16 16:45:00                                                NaN
#
#                                                     Time Series (5min)
# 1. Information                                                     NaN
# ...

# %%
df.isna().sum()
# Out:
# Meta Data             100
# Time Series (5min)      6
# dtype: int64
